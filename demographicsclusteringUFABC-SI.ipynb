# %%
df = pd.read_csv(r'C:\Users\manci\Documents\UFABC\Sistemas Inteligentes\Projeto\microdados_perfil_discente_2018.csv', encoding='utf8', sep = ';')

# %%
import pandas as pd

# %%
df.
# Out:
#                          Sim
# 9900                                                NaN
# 9901                                                NaN
# 9902                                                NaN
# 9903                                                Sim
# 9904                                                NaN
# 9905                                                NaN
# 9906                                                NaN
# 9907                                                NaN
# 9908                                                NaN
# 9909                                                NaN
# 9910                                                Sim
# 9911                                                NaN
# 9912                                                Sim
# 9913                                                NaN
# 9914                                                NaN
# 9915                                                NaN
# ...
